# %%
# !pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 62.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 54.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 6.0 MB/s eta 0:00:00

# %%
# !pip install pandas
# !pip install gTTS

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import random
from gtts import gTTS
import os

# Step 2: Create a function to provide random diet recommendations based on pregnancy month and dietary preferences
def recommend_diet(pregnancy_month, preferences):
    diet_charts = []

    # Define sample diet charts for each trimester and dietary preference
    for preference in preferences:
        if pregnancy_month <= 3:  # First trimester (1-3 months)
            if preference == 'Veg':
                diet_chart1 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["फल के साथ ओट्स", "सब्जियों के साथ पोहा", "सब्जियों का उपमा", "दूध के साथ दलिया", "सांभर के साथ इडली", "बेसन चिल्ला", "दही के साथ पराठा"],
                    "दोपहर का भोजन": ["दाल, चावल, सलाद", "राजमा और रोटी", "सब्जी पुलाव", "चोले और चावल", "पनीर सब्जी", "मिक्स वेज करी और रोटी", "खिचड़ी"],
                    "रात का खाना": ["रोटी के साथ मिक्स सब्जी", "पालक पनीर और चावल", "दाल और रोटी", "आलू गोभी के साथ चावल", "रोटी के साथ भिंडी", "भरवां रोटी और दही", "सब्जी का सूप और टोस्ट"]
                })
                diet_chart2 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["मेथी पराठा", "शहद के साथ दलिया", "सब्जी पराठा", "पाव भाजी", "दही के साथ फलों का सलाद", "पोंगल", "सूजी हलवा"],
                    "दोपहर का भोजन": ["वेजिटेबल बिरयानी", "तूर दाल और रोटी", "चना मसाला और चावल", "पनीर बटर मसाला और रोटी", "मेथी थेपला और दही", "खिचड़ी और रायता", "दाल फ्राई और चावल"],
                    "रात का खाना": ["वेजिटेबल कोरमा और चावल", "रोटी के साथ आलू मटर", "गोभी मसाला और रोटी", "मिक्स दाल सूप", "भरवां शिमला मिर्च और रोटी", "रोटी और मसूर दाल", "मेथी थेपला और दही"]
                })
                diet_charts.append(random.choice([diet_chart1, diet_chart2]))
            elif preference == 'Non-Veg':
                diet_chart1 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["उबले अंडे और टोस्ट", "चिकन सैंडविच", "सब्जियों के साथ ऑमलेट", "शहद के साथ पैनकेक", "स्क्रैम्बल्ड एग्स", "ग्रिल्ड चिकन और टोस्ट", "अंडा पराठा"],
                    "दोपहर का भोजन": ["चिकन करी और चावल", "फिश करी और रोटी", "एग बिरयानी", "चिकन पुलाव", "फिश फ्राई और चावल", "मटन करी और रोटी", "चिकन स्टू"],
                    "रात का खाना": ["एग करी और चावल", "ग्रिल्ड चिकन सलाद", "फिश करी और रोटी", "चावल और मटन स्टू", "चिकन सूप और चावल", "फिश करी और रोटी", "अंडा भुर्जी और पराठा"]
                })
                diet_chart2 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["चिकन कबाब", "एग सैंडविच", "स्क्रैम्बल्ड एग्स", "उबला चिकन और टोस्ट", "एग भुर्जी", "फिश फ्राई", "ग्रिल्ड चिकन और सब्जियाँ"],
                    "दोपहर का भोजन": ["चिकन मसाला और चावल", "फिश करी और रोटी", "मटन बिरयानी", "एग करी और चावल", "ग्रिल्ड चिकन और सलाद", "फिश मसाला और रोटी", "चिकन स्टू और चावल"],
                    "रात का खाना": ["ग्रिल्ड चिकन और रोटी", "मटन स्टू और चावल", "चिकन करी और चावल", "फिश करी और रोटी", "चिकन सूप और रोटी", "एग करी और चावल", "फिश स्टू और चावल"]
                })
                diet_charts.append(random.choice([diet_chart1, diet_chart2]))
            elif preference == 'Egg':
                diet_chart1 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["उबले अंडे और टोस्ट", "एग पराठा", "ऑमलेट और टोस्ट", "फ्रेंच टोस्ट और अंडा", "एग डोसा", "एग सैंडविच", "स्क्रैम्बल्ड एग्स"],
                    "दोपहर का भोजन": ["अंडा करी और चावल", "दाल और उबला अंडा", "एग बिरयानी", "रोटी और एग भुर्जी", "एग पुलाव", "अंडा करी और चावल", "चावल और एग सलाद"],
                    "रात का खाना": ["एग खिचड़ी", "रोटी और अंडा करी", "एग फ्राइड राइस", "एग मसाला और रोटी", "एग सूप और चावल", "रोटी और एग कोरमा", "अंडा करी"]
                })
                diet_chart2 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["एग सैंडविच", "स्क्रैम्बल्ड एग और टोस्ट", "उबले अंडे और सब्जियाँ", "एग पराठा", "फ्रेंच टोस्ट और अंडा", "स्क्रैम्बल्ड एग्स", "ऑमलेट और सब्जियाँ"],
                    "दोपहर का भोजन": ["अंडा करी और चपाती", "चावल और अंडा फ्राई", "एग बिरयानी", "उबले अंडे और सलाद", "अंडा करी और चावल", "चपाती और एग भुर्जी", "एग मसाला और रोटी"],
                    "रात का खाना": ["अंडा करी और चावल", "अंडा सूप और चावल", "एग फ्राइड राइस", "रोटी और अंडा करी", "अंडा कोरमा और चावल", "अंडा स्टू और चपाती", "अंडा और सब्जी करी"]
                })
                diet_charts.append(random.choice([diet_chart1, diet_chart2]))

        elif 4 <= pregnancy_month <= 6:  # Second trimester (4-6 months)
            # Add more diet charts for the second trimester
            if preference == 'Veg':
                diet_chart1 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["फलों के साथ ओट्स", "सब्जियों के साथ पोहा", "सब्जी उपमा", "दूध के साथ दलिया", "इडली और सांभर", "बेसन चीला", "दही के साथ पराठा"],
                    "दोपहर का भोजन": ["दाल, चावल, सलाद", "राजमा और चपाती", "सब्जी पुलाव", "चोले और चावल", "पनीर की सब्जी", "मिक्स वेज करी और चपाती", "खिचड़ी"],
                    "रात का खाना": ["मिक्स वेज के साथ रोटी", "पालक पनीर और चावल", "दाल और चपाती", "आलू गोभी के साथ चावल", "भिंडी के साथ चपाती", "दही के साथ भरी हुई रोटी", "सब्जी सूप और टोस्ट"]
                })
                diet_chart2 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["मेथी पराठा", "शहद के साथ दलिया", "सब्जी पराठा", "पाव भाजी", "दही के साथ फलों का सलाद", "पोंगल", "सूजी हलवा"],
                    "दोपहर का भोजन": ["वेज बिरयानी", "तूर दाल और चपाती", "चना मसाला और चावल", "रोटी के साथ पनीर बटर मसाला", "मेथी थेपला और दही", "खिचड़ी और रायता", "दाल फ्राई और चावल"],
                    "रात का खाना": ["वेज कोरमा और चावल", "आलू मटर के साथ चपाती", "गोभी मसाला और रोटी", "मिक्स दाल का सूप", "भरवां शिमला मिर्च और रोटी", "मसूर दाल और रोटी", "मेथी थेपला और दही"]
                })
                diet_charts.append(random.choice([diet_chart1, diet_chart2]))
            elif preference == 'Non-Veg':
                diet_chart1 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["उबले अंडे और टोस्ट", "चिकन सैंडविच", "सब्जियों के साथ ऑमलेट", "शहद के साथ पैनकेक", "स्क्रैम्बल्ड अंडे", "ग्रिल्ड चिकन और टोस्ट", "एग पराठा"],
                    "दोपहर का भोजन": ["चिकन करी और चावल", "फिश करी और चपाती", "एग बिरयानी", "चिकन पुलाव", "फिश फ्राई और चावल", "मटन करी और चपाती", "चिकन स्टू"],
                    "रात का खाना": ["अंडा करी और चावल", "ग्रिल्ड चिकन सलाद", "फिश करी और रोटी", "चावल और मटन स्टू", "चिकन सूप और चावल", "फिश करी और चपाती", "अंडा भुर्जी और पराठा"]
                })
                diet_chart2 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["चिकन कबाब", "अंडा सैंडविच", "स्क्रैम्बल्ड अंडे", "उबला चिकन और टोस्ट", "अंडा भुर्जी", "फिश फ्राई", "ग्रिल्ड चिकन और सब्जियाँ"],
                    "दोपहर का भोजन": ["चिकन मसाला और चावल", "फिश करी और रोटी", "मटन बिरयानी", "अंडा करी और चावल", "ग्रिल्ड चिकन और सलाद", "फिश मसाला और चपाती", "चिकन स्टू और चावल"],
                    "रात का खाना": ["ग्रिल्ड चिकन और चपाती", "मटन स्टू और चावल", "चिकन करी और चावल", "फिश करी और चपाती", "चिकन सूप और रोटी", "अंडा करी और चावल", "फिश स्टू और चावल"]
                })
                diet_charts.append(random.choice([diet_chart1, diet_chart2]))
            elif preference == 'Egg':
                diet_chart1 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["उबले अंडे और टोस्ट", "अंडा पराठा", "ऑमलेट और टोस्ट", "फ्रेंच टोस्ट और अंडा", "अंडा डोसा", "अंडा सैंडविच", "स्क्रैम्बल्ड अंडे"],
                    "दोपहर का भोजन": ["अंडा करी और चावल", "दाल और उबला अंडा", "अंडा बिरयानी", "चपाती और अंडा भुर्जी", "अंडा पुलाव", "अंडा करी और चावल", "चावल और अंडा सलाद"],
                    "रात का खाना": ["अंडा खिचड़ी", "रोटी और अंडा करी", "अंडा फ्राइड राइस", "अंडा मसाला और रोटी", "अंडा सूप और चावल", "चपाती और अंडा कोरमा", "अंडा करी"]
                })
                diet_chart2 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["अंडा सैंडविच", "अंडा स्क्रैम्बल और टोस्ट", "उबले अंडे और सब्जियाँ", "अंडा पराठा", "फ्रेंच टोस्ट और अंडा", "स्क्रैम्बल्ड अंडे", "ऑमलेट और सब्जियाँ"],
                    "दोपहर का भोजन": ["अंडा करी और चपाती", "चावल और अंडा फ्राई", "अंडा बिरयानी", "उबले अंडे और सलाद", "अंडा करी और चावल", "चपाती और अंडा भुर्जी", "अंडा मसाला और रोटी"],
                    "रात का खाना": ["अंडा करी और चावल", "अंडा सूप और चावल", "अंडा फ्राइड राइस", "रोटी और अंडा करी", "अंडा कोरमा और चावल", "अंडा स्टू और चपाती", "अंडा और सब्जी करी"]
                })
                diet_charts.append(random.choice([diet_chart1, diet_chart2]))
            pass

        elif 7 <= pregnancy_month <= 9:  # Third trimester (7-9 months)
            # Add more diet charts for the third trimester
            if preference == 'Veg':
                diet_chart1 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["फलों के साथ ओट्स", "पोहा और सब्जियाँ", "सब्ज़ी उपमा", "दलीया और दूध", "इडली और सांबर", "बेसन चिल्ला", "पराठा और दही"],
                    "दोपहर का भोजन": ["दाल, चावल, सलाद", "राजमा और चपाती", "सब्ज़ी पुलाव", "चोलें और चावल", "पनीर सब्ज़ी", "मिक्स वेज करी और चपाती", "खिचड़ी"],
                    "रात का खाना": ["रोटी और मिक्स वेज", "पालक पनीर और चावल", "दाल और चपाती", "चावल और आलू गोभी", "चपाती और भिंडी", "स्टफ्ड रोटी और दही", "सब्ज़ी सूप और टोस्ट"]
                })
                diet_chart2 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["मेथी पराठा", "हनी के साथ दलिया", "सब्ज़ी पराठा", "पाव भाजी", "फलों का सलाद और दही", "पोंगल", "सूजी हलवा"],
                    "दोपहर का भोजन": ["सब्ज़ी बिरयानी", "तूर दाल और चपाती", "चना मसाला और चावल", "पनीर बटर मसाला और रोटी", "मेथी थेपला और दही", "खिचड़ी और रायता", "दाल फ्राई और चावल"],
                    "रात का खाना": ["सब्ज़ी कोरमा और चावल", "चपाती और आलू मटर", "गोबी मसाला और रोटी", "मिक्स दाल सूप", "स्टफ्ड शिमला मिर्च और रोटी", "रोटी और मसूर दाल", "मेथी थेपला और दही"]
                })
                diet_charts.append(random.choice([diet_chart1, diet_chart2]))
            elif preference == 'Non-Veg':
                diet_chart1 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["उबले अंडे और टोस्ट", "चिकन सैंडविच", "सब्ज़ियों के साथ आमलेट", "हनी के साथ पैनकेक", "स्क्रैम्बल अंडे", "ग्रिल्ड चिकन और टोस्ट", "अंडा पराठा"],
                    "दोपहर का भोजन": ["चिकन करी और चावल", "फिश करी और चपाती", "एग बिरयानी", "चिकन पुलाव", "फिश फ्राई और चावल", "मटन करी और चपाती", "चिकन स्टू"],
                    "रात का खाना": ["एग करी और चावल", "ग्रिल्ड चिकन सलाद", "फिश करी और रोटी", "चावल और मटन स्टू", "चिकन सूप और चावल", "फिश करी और चपाती", "एग भुर्जी और पराठा"]
                })
                diet_chart2 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["चिकन कबाब", "अंडा सैंडविच", "स्क्रैम्बल अंडे", "उबला चिकन और टोस्ट", "अंडा भुर्जी", "फिश फ्राई", "ग्रिल्ड चिकन और सब्ज़ियाँ"],
                    "दोपहर का भोजन": ["चिकन मसाला और चावल", "फिश करी और रोटी", "मटन बिरयानी", "अंडा करी और चावल", "ग्रिल्ड चिकन और सलाद", "फिश मसाला और चपाती", "चिकन स्टू और चावल"],
                    "रात का खाना": ["ग्रिल्ड चिकन और चपाती", "मटन स्टू और चावल", "चिकन करी और चावल", "फिश करी और चपाती", "चिकन सूप और रोटी", "अंडा करी और चावल", "फिश स्टू और चावल"]
                })
                diet_charts.append(random.choice([diet_chart1, diet_chart2]))
            elif preference == 'Egg':
                diet_chart1 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["उबले हुए अंडे और टोस्ट", "अंडा पराठा", "ऑमलेट और टोस्ट", "फ्रेंच टोस्ट और अंडा", "अंडा डोसा", "अंडा सैंडविच", "स्क्रैम्बल अंडे"],
                    "दोपहर का भोजन": ["अंडा करी और चावल", "दाल और उबला हुआ अंडा", "अंडा बिरयानी", "चपाती और अंडा भुर्जी", "अंडा पुलाव", "अंडा करी और चावल", "चावल और अंडा सलाद"],
                    "रात का खाना": ["अंडा खिचड़ी", "रोटी और अंडा करी", "अंडा फ्राइड राइस", "अंडा मसाला और रोटी", "अंडा सूप और चावल", "चपाती और अंडा कोरमा", "अंडा करी"]
                })

                diet_chart2 = pd.DataFrame({
                    "दिन": ["सोमवार", "मंगलवार", "बुधवार", "गुरुवार", "शुक्रवार", "शनिवार", "रविवार"],
                    "नाश्ता": ["अंडा सैंडविच", "अंडा स्क्रैंबल और टोस्ट", "उबले हुए अंडे और सब्जियाँ", "अंडा पराठा", "फ्रेंच टोस्ट और अंडा", "स्क्रैम्बल अंडे", "ऑमलेट और सब्जियाँ"],
                    "दोपहर का भोजन": ["अंडा करी और चपाती", "चावल और अंडा फ्राई", "अंडा बिरयानी", "उबले हुए अंडे और सलाद", "अंडा करी और चावल", "चपाती और अंडा भुर्जी", "अंडा मसाला और रोटी"],
                    "रात का खाना": ["अंडा करी और चावल", "अंडा सूप और चावल", "अंडा फ्राइड राइस", "रोटी और अंडा करी", "अंडा कोरमा और चावल", "अंडा स्टीव और चपाती", "अंडा और सब्जी करी"]
                })
                diet_charts.append(random.choice([diet_chart1, diet_chart2]))
            pass


    # Combine all selected diet charts into a single output
    combined_chart = pd.concat(diet_charts)

    # Convert the diet chart to a text format for speech
    recommendations = combined_chart.to_string(index=False)

    # Convert the text to speech and save it as an audio file
    tts = gTTS(text=recommendations, lang='hi')
    audio_file = "diet_recommendation.mp3"
    tts.save(audio_file)

    # Return the combined diet chart and path to the audio file
    return combined_chart, audio_file

# Streamlit UI
st.title("Pregnancy Diet Recommendations")
st.markdown("""
    Enter your pregnancy month and dietary preference to get a weekly diet chart.
""")

# Inputs from the user
pregnancy_month = st.slider("Pregnancy Month", min_value=1, max_value=9, step=1)
preferences = st.multiselect("Diet Preferences", ["Veg", "Non-Veg", "Egg"])

# Button to get diet recommendations
if st.button("Get Diet Recommendation"):
    # Get the diet recommendations and audio file
    diet_chart, audio_file = recommend_diet(pregnancy_month, preferences)

    # Display the diet chart in a table
    st.write("### Weekly Diet Chart")
    st.dataframe(diet_chart)

    # Provide the audio file for download
    st.write("### Listen to the Diet Recommendation")
    st.audio(audio_file)
# Out:
# Writing app.py

# %%
# !curl https://loca.lt/mytunnelpassword
# Out:
# 35.240.141.17

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
# Out:
# your url is: https://cold-items-shine.loca.lt
